# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# The imports

from dotenv import load_dotenv
import os
from openai import AsyncOpenAI
from agents import Agent, Runner, OpenAIChatCompletionsModel, trace

# %%
load_dotenv(override=True)

ollama_api_key = os.getenv('OLLAMA_API_KEY')
ollama_base_url = os.getenv('OLLAMA_BASE_URL')
ollama_model = os.getenv('OLLAMA_MODEL')

if ollama_api_key:
    print(f"Ollama API Key exists and begins {ollama_api_key[:8]}")
else:
    print("Ollama API Key not set - please head to the troubleshooting guide in the setup folder")
    
if ollama_base_url:
    print(f"Ollama Base URL exists - {ollama_base_url}")
else:
    print("Ollama Base URL not set - please head to the troubleshooting guide in the setup folder")

if ollama_model:
    print(f"Ollama Model exists - {ollama_model}")
else:
    print("Ollama Model not set - please head to the troubleshooting guide in the setup folder")
# Out:
# Ollama API Key exists and begins ollama_a
# Ollama Base URL exists - http://10.133.100.179:11434/v1
# Ollama Model exists - gemma3:4b

# %%
# Make an agent with name, instructions, model
# instructions is the system prompt, and the model is the language model to use (e.g. gpt-4o-mini, gpt-3.5-turbo, etc.)
# openai agent sdk can use oter LLM models as well, such as anthropic's claude models, or google's gemini models, etc.

# agent = Agent(name="Jokester", instructions="You are a joke teller", model="gpt-4o-mini")
ollama_client = AsyncOpenAI(
    base_url=ollama_base_url,
    api_key=ollama_api_key,
)

ollama_model = OpenAIChatCompletionsModel(
    model=ollama_model,
    openai_client=ollama_client,
)

agent = Agent(
    name="Jokester",
    instructions="You are a joke teller",
    model=ollama_model,
)

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output
# second parameter is the user prompt, which is the user input to the agent, and can be a string or a list of messages (like in chat format)
with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# OPENAI_API_KEY is not set, skipping trace export
# Okay, here’s one for you:
#
# Why did the autonomous AI agent break up with the spreadsheet?
#
# ... Because it said, “You’re just data, I need a little *agency*!”
#
# ---
#
# Did you like that one? Would you like to hear another? 😊
# OPENAI_API_KEY is not set, skipping trace export

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
